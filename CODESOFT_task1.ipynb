# %% [markdown]
# <a href="https://colab.research.google.com/github/MaraBhargavi/CODSOFT/blob/codsoft_task1/CODESOFT_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import os

TASKS_FILE = "tasks.json"
def load_tasks():
    if os.path.exists(TASKS_FILE):
        with open(TASKS_FILE, "r") as file:
            return json.load(file)
    return []
def save_tasks(tasks):
    with open(TASKS_FILE, "w") as file:
        json.dump(tasks, file, indent=4)
def show_tasks(tasks):
    if not tasks:
        print("\nNo tasks available.\n")
        return
    print("\n------ Your To-Do List ------")
    for i, task in enumerate(tasks, 1):
        status = "✔ Done" if task["completed"] else "✗ Pending"
        print(f"{i}. {task['title']}  [{status}]")
    print("------------------------------\n")
def add_task(tasks):
    title = input("Enter task title: ")
    tasks.append({"title": title, "completed": False})
    save_tasks(tasks)
    print("Task added successfully!\n")
def update_task(tasks):
    show_tasks(tasks)
    try:
        task_num = int(input("Enter task number to update: ")) - 1
        tasks[task_num]["title"] = input("Enter new task title: ")
        save_tasks(tasks)
        print("Task updated!\n")
    except (ValueError, IndexError):
        print("Invalid task number!\n")
def complete_task(tasks):
    show_tasks(tasks)
    try:
        task_num = int(input("Enter task number to mark completed: ")) - 1
        tasks[task_num]["completed"] = True
        save_tasks(tasks)
        print("Task marked as completed!\n")
    except (ValueError, IndexError):
        print("Invalid task number!\n")
def delete_task(tasks):
    show_tasks(tasks)
    try:
        task_num = int(input("Enter task number to delete: ")) - 1
        tasks.pop(task_num)
        save_tasks(tasks)
        print("Task deleted!\n")
    except (ValueError, IndexError):
        print("Invalid task number!\n")
def main():
    tasks = load_tasks()
    while True:
        print("=== TO-DO LIST MENU ===")
        print("1. View Tasks")
        print("2. Add Task")
        print("3. Update Task")
        print("4. Mark Task Completed")
        print("5. Delete Task")
        print("6. Exit")

        choice = input("\nEnter your choice: ")

        if choice == "1":
            show_tasks(tasks)
        elif choice == "2":
            add_task(tasks)
        elif choice == "3":
            update_task(tasks)
        elif choice == "4":
            complete_task(tasks)
        elif choice == "5":
            delete_task(tasks)
        elif choice == "6":
            print("Exiting... Goodbye!")
            break
        else:
            print("Invalid choice. Try again!\n")
if __name__ == "__main__":
    main()
# Out:
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 1
#
# No tasks available.
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 2
# Enter task title: DANCE
# Task added successfully!
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 2
# Enter task title: SINGING
# Task added successfully!
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 1
#
# ------ Your To-Do List ------
# 1. DANCE  [✗ Pending]
# 2. SINGING  [✗ Pending]
# ------------------------------
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 3
#
# ------ Your To-Do List ------
# 1. DANCE  [✗ Pending]
# 2. SINGING  [✗ Pending]
# ------------------------------
#
# Enter task number to update: 2
# Enter new task title: GYM
# Task updated!
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 4
#
# ------ Your To-Do List ------
# 1. DANCE  [✗ Pending]
# 2. GYM  [✗ Pending]
# ------------------------------
#
# Enter task number to mark completed: 2
# Task marked as completed!
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 1
#
# ------ Your To-Do List ------
# 1. DANCE  [✗ Pending]
# 2. GYM  [✔ Done]
# ------------------------------
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 5
#
# ------ Your To-Do List ------
# 1. DANCE  [✗ Pending]
# 2. GYM  [✔ Done]
# ------------------------------
#
# Enter task number to delete: 2
# Task deleted!
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 1
#
# ------ Your To-Do List ------
# 1. DANCE  [✗ Pending]
# ------------------------------
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 6
# Exiting... Goodbye!
