# %% [markdown]
# <a href="https://colab.research.google.com/github/MaraBhargavi/CODSOFT/blob/main/CODSOFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TASK 1:**
# TO-DO LIST

# %%
import json
import os

TASKS_FILE = "tasks.json"
def load_tasks():
    if os.path.exists(TASKS_FILE):
        with open(TASKS_FILE, "r") as file:
            return json.load(file)
    return []
def save_tasks(tasks):
    with open(TASKS_FILE, "w") as file:
        json.dump(tasks, file, indent=4)
def show_tasks(tasks):
    if not tasks:
        print("\nNo tasks available.\n")
        return
    print("\n------ Your To-Do List ------")
    for i, task in enumerate(tasks, 1):
        status = "✔ Done" if task["completed"] else "✗ Pending"
        print(f"{i}. {task['title']}  [{status}]")
    print("------------------------------\n")
def add_task(tasks):
    title = input("Enter task title: ")
    tasks.append({"title": title, "completed": False})
    save_tasks(tasks)
    print("Task added successfully!\n")
def update_task(tasks):
    show_tasks(tasks)
    try:
        task_num = int(input("Enter task number to update: ")) - 1
        tasks[task_num]["title"] = input("Enter new task title: ")
        save_tasks(tasks)
        print("Task updated!\n")
    except (ValueError, IndexError):
        print("Invalid task number!\n")
def complete_task(tasks):
    show_tasks(tasks)
    try:
        task_num = int(input("Enter task number to mark completed: ")) - 1
        tasks[task_num]["completed"] = True
        save_tasks(tasks)
        print("Task marked as completed!\n")
    except (ValueError, IndexError):
        print("Invalid task number!\n")
def delete_task(tasks):
    show_tasks(tasks)
    try:
        task_num = int(input("Enter task number to delete: ")) - 1
        tasks.pop(task_num)
        save_tasks(tasks)
        print("Task deleted!\n")
    except (ValueError, IndexError):
        print("Invalid task number!\n")
def main():
    tasks = load_tasks()
    while True:
        print("=== TO-DO LIST MENU ===")
        print("1. View Tasks")
        print("2. Add Task")
        print("3. Update Task")
        print("4. Mark Task Completed")
        print("5. Delete Task")
        print("6. Exit")

        choice = input("\nEnter your choice: ")

        if choice == "1":
            show_tasks(tasks)
        elif choice == "2":
            add_task(tasks)
        elif choice == "3":
            update_task(tasks)
        elif choice == "4":
            complete_task(tasks)
        elif choice == "5":
            delete_task(tasks)
        elif choice == "6":
            print("Exiting... Goodbye!")
            break
        else:
            print("Invalid choice. Try again!\n")
if __name__ == "__main__":
    main()
# Out:
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 1
#
# No tasks available.
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 2
# Enter task title: GYM
# Task added successfully!
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 2
# Enter task title: SHOPPING
# Task added successfully!
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 3
#
# ------ Your To-Do List ------
# 1. GYM  [✗ Pending]
# 2. SHOPPING  [✗ Pending]
# ------------------------------
#
# Enter task number to update: 2
# Enter new task title: RESTAURANT
# Task updated!
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 4
#
# ------ Your To-Do List ------
# 1. GYM  [✗ Pending]
# 2. RESTAURANT  [✗ Pending]
# ------------------------------
#
# Enter task number to mark completed: 1
# Task marked as completed!
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 1
#
# ------ Your To-Do List ------
# 1. GYM  [✔ Done]
# 2. RESTAURANT  [✗ Pending]
# ------------------------------
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 5
#
# ------ Your To-Do List ------
# 1. GYM  [✔ Done]
# 2. RESTAURANT  [✗ Pending]
# ------------------------------
#
# Enter task number to delete: 2
# Task deleted!
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 2
# Enter task title: SHOPPING
# Task added successfully!
#
# === TO-DO LIST MENU ===
# 1. View Tasks
# 2. Add Task
# 3. Update Task
# 4. Mark Task Completed
# 5. Delete Task
# 6. Exit
#
# Enter your choice: 6
# Exiting... Goodbye!

# %% [markdown]
# **TASK 2:** CALCULATOR

# %%
print("===== SIMPLE CALCULATOR =====")
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
print("\nChoose an operation:")
print("1. Addition (+)")
print("2. Subtraction (-)")
print("3. Multiplication (*)")
print("4. Division (/)\n")
choice = input("Enter your choice (1/2/3/4): ")
if choice == '1':
    result = num1 + num2
    print(f"\nResult: {num1} + {num2} = {result}")
elif choice == '2':
    result = num1 - num2
    print(f"\nResult: {num1} - {num2} = {result}")
elif choice == '3':
    result = num1 * num2
    print(f"\nResult: {num1} × {num2} = {result}")
elif choice == '4':
    if num2 != 0:
        result = num1 / num2
        print(f"\nResult: {num1} ÷ {num2} = {result}")
    else:
        print("\nError: Division by zero is not allowed.")
else:
    print("\nInvalid choice! Please select 1, 2, 3, or 4.")
print("\n===== PROGRAM FINISHED =====")
# Out:
# ===== SIMPLE CALCULATOR =====
# Enter first number: 20987
# Enter second number: 243565
#
# Choose an operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
#
# Enter your choice (1/2/3/4): 1
#
# Result: 20987.0 + 243565.0 = 264552.0
#
# ===== PROGRAM FINISHED =====

# %% [markdown]
# **TASK 3:** PASSWORD GENERATOR

# %%
import string
import random
print("===== PASSWORD GENERATOR WITH STRENGTH LEVELS =====")
length = int(input("Enter the desired password length: "))
characters = string.ascii_letters + string.digits + string.punctuation
password = ''.join(random.choice(characters) for _ in range(length))
def check_strength(pw):
    has_upper = any(ch.isupper() for ch in pw)
    has_lower = any(ch.islower() for ch in pw)
    has_digit = any(ch.isdigit() for ch in pw)
    has_symbol = any(ch in string.punctuation for ch in pw)
    if length < 6:
        return "Weak"
    elif (has_upper + has_lower + has_digit + has_symbol) <= 2:
        return "Weak"
    if 6 <= length < 10:
        return "Medium"
    if length >= 10 and has_upper and has_lower and has_digit and has_symbol:
        return "Strong"
    return "Medium"
strength = check_strength(password)
print("\nYour Generated Password:")
print(password)
print("\nPassword Strength:", strength)
print("\n===== END =====")
# Out:
# ===== PASSWORD GENERATOR WITH STRENGTH LEVELS =====
# Enter the desired password length: 12
#
# Your Generated Password:
# GPHZ0wB?l{dX
#
# Password Strength: Strong
#
# ===== END =====

# %% [markdown]
# **TASK 4:** ROCK-PAPER-SCISSORS GAME

# %%
import random
print("===== ROCK - PAPER - SCISSORS GAME =====")
user_score = 0
computer_score = 0
choices = ["rock", "paper", "scissors"]
while True:
    print("\nChoose your option:")
    print("1. rock")
    print("2. paper")
    print("3. scissors")
    user_choice = input("Enter your choice: ").lower()
    if user_choice not in choices:
        print("Invalid choice! Please choose rock, paper or scissors.")
        continue
    computer_choice = random.choice(choices)
    print(f"\nYou chose: {user_choice}")
    print(f"Computer chose: {computer_choice}")
    if user_choice == computer_choice:
        print("Result: It's a Tie!")
    elif (user_choice == "rock" and computer_choice == "scissors") \
        or (user_choice == "paper" and computer_choice == "rock") \
        or (user_choice == "scissors" and computer_choice == "paper"):
        print("Result: You Win!")
        user_score += 1
    else:
        print("Result: You Lose!")
        computer_score += 1
    print(f"\nScore -> You: {user_score} | Computer: {computer_score}")
    play_again = input("\nDo you want to play again? (yes/no): ").lower()
    if play_again != "yes":
        print("\nThank you for playing!")
        break
print("\n===== GAME OVER =====")
# Out:
# ===== ROCK - PAPER - SCISSORS GAME =====
#
# Choose your option:
# 1. rock
# 2. paper
# 3. scissors
# Enter your choice: 2
# Invalid choice! Please choose rock, paper or scissors.
#
# Choose your option:
# 1. rock
# 2. paper
# 3. scissors
# Enter your choice: ROCK
#
# You chose: rock
# Computer chose: rock
# Result: It's a Tie!
#
# Score -> You: 0 | Computer: 0
#
# Do you want to play again? (yes/no): YES
#
# Choose your option:
# 1. rock
# 2. paper
# 3. scissors
# Enter your choice: SCISSORS
#
# You chose: scissors
# Computer chose: paper
# Result: You Win!
#
# Score -> You: 1 | Computer: 0
#
# Do you want to play again? (yes/no): NO
#
# Thank you for playing!
#
# ===== GAME OVER =====

# %% [markdown]
# **TASK 5:** CONTACT BOOK

# %%
contacts = {}

def add_contact():
    print("\n--- Add New Contact ---")
    name = input("Enter name: ")
    phone = input("Enter phone number: ")
    email = input("Enter email: ")
    address = input("Enter address: ")
    contacts[name] = {
        "phone": phone,
        "email": email,
        "address": address
    }
    print("\nContact added successfully!")
def view_contacts():
    print("\n--- Contact List ---")
    if not contacts:
        print("No contacts found.")
    else:
        for name, details in contacts.items():
            print(f"\nName: {name}")
            print(f"Phone: {details['phone']}")
            print(f"Email: {details['email']}")
            print(f"Address: {details['address']}")
def search_contact():
    print("\n--- Search Contact ---")
    search_term = input("Enter name or phone to search: ")
    found = False
    for name, details in contacts.items():
        if search_term.lower() in name.lower() or search_term in details['phone']:
            print(f"\nName: {name}")
            print(f"Phone: {details['phone']}")
            print(f"Email: {details['email']}")
            print(f"Address: {details['address']}")
            found = True
    if not found:
        print("\nNo matching contact found.")
def update_contact():
    print("\n--- Update Contact ---")
    name = input("Enter the name of the contact to update: ")
    if name in contacts:
        print("\nWhat do you want to update?")
        print("1. Phone Number")
        print("2. Email")
        print("3. Address")
        print("4. All Fields")
        choice = input("Enter choice: ")
        if choice == "1":
            contacts[name]['phone'] = input("Enter new phone number: ")
        elif choice == "2":
            contacts[name]['email'] = input("Enter new email: ")
        elif choice == "3":
            contacts[name]['address'] = input("Enter new address: ")
        elif choice == "4":
            contacts[name]['phone'] = input("Enter new phone number: ")
            contacts[name]['email'] = input("Enter new email: ")
            contacts[name]['address'] = input("Enter new address: ")
        else:
            print("Invalid choice.")
        print("\nContact updated successfully!")
    else:
        print("\nContact not found.")
def delete_contact():
    print("\n--- Delete Contact ---")
    name = input("Enter the name of the contact to delete: ")
    if name in contacts:
        del contacts[name]
        print("\nContact deleted successfully!")
    else:
        print("\nContact not found.")
def menu():
    while True:
        print("\n===== CONTACT MANAGEMENT SYSTEM =====")
        print("1. Add Contact")
        print("2. View Contacts")
        print("3. Search Contact")
        print("4. Update Contact")
        print("5. Delete Contact")
        print("6. Exit")
        choice = input("\nEnter your choice: ")
        if choice == "1":
            add_contact()
        elif choice == "2":
            view_contacts()
        elif choice == "3":
            search_contact()
        elif choice == "4":
            update_contact()
        elif choice == "5":
            delete_contact()
        elif choice == "6":
            print("\nExiting program. Goodbye!")
            break
        else:
            print("\nInvalid choice. Please try again.")
menu()
# Out:
# ===== CONTACT MANAGEMENT SYSTEM =====
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
#
# Enter your choice: 1
#
# --- Add New Contact ---
# Enter name: ABK
# Enter phone number: 1234567891
# Enter email: ABK@GMAIL.COM
# Enter address: DST
#
# Contact added successfully!
#
# ===== CONTACT MANAGEMENT SYSTEM =====
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
#
# Enter your choice: 1
#
# --- Add New Contact ---
# Enter name: MLV
# Enter phone number: 2345678912
# Enter email: MLV
# Enter address: AWE
#
# Contact added successfully!
#
# ===== CONTACT MANAGEMENT SYSTEM =====
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
#
# Enter your choice: 2
#
# --- Contact List ---
#
# Name: ABK
# Phone: 1234567891
# Email: ABK@GMAIL.COM
# Address: DST
#
# Name: MLV
# Phone: 2345678912
# Email: MLV
# Address: AWE
#
# ===== CONTACT MANAGEMENT SYSTEM =====
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
#
# Enter your choice: 3
#
# --- Search Contact ---
# Enter name or phone to search: MLV
#
# Name: MLV
# Phone: 2345678912
# Email: MLV
# Address: AWE
#
# ===== CONTACT MANAGEMENT SYSTEM =====
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
#
# Enter your choice: 4
#
# --- Update Contact ---
# Enter the name of the contact to update: MLV
#
# What do you want to update?
# 1. Phone Number
# 2. Email
# 3. Address
# 4. All Fields
# Enter choice: 2
# Enter new email: MLV@GMAIL.COM
#
# Contact updated successfully!
#
# ===== CONTACT MANAGEMENT SYSTEM =====
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
#
# Enter your choice: 2
#
# --- Contact List ---
#
# Name: ABK
# Phone: 1234567891
# Email: ABK@GMAIL.COM
# Address: DST
#
# Name: MLV
# Phone: 2345678912
# Email: MLV@GMAIL.COM
# Address: AWE
#
# ===== CONTACT MANAGEMENT SYSTEM =====
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
#
# Enter your choice: 5
#
# --- Delete Contact ---
# Enter the name of the contact to delete: MLV
#
# Contact deleted successfully!
#
# ===== CONTACT MANAGEMENT SYSTEM =====
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
#
# Enter your choice: 2
#
# --- Contact List ---
#
# Name: ABK
# Phone: 1234567891
# Email: ABK@GMAIL.COM
# Address: DST
#
# ===== CONTACT MANAGEMENT SYSTEM =====
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
#
# Enter your choice: 6
#
# Exiting program. Goodbye!
